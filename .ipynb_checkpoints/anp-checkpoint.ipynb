# %% [markdown]
# ## Table Of Contents
# * [Purpose](#Purpose)
# * [Dependencies](#Dependencies)
#     * [Python and Anaconda installation](#Python-and-Anaconda-installation)
#     * [A Python kernel for Jupyter notebooks](#A-Python-kernel-for-Jupyter-notebooks)
#     * [Load the Python Packages](#Load-the-Python-Packages)
# * [Inputs](#inputs)
# * [Outputs](#Outputs)
#     * [Tabular Data](#Tabular-Data)
#     * [Map](#Map)
#     * [Bar Chart](#Bar-Chart)
# * [Code](#Code)
# * [Provenance](#Provenance)
# * [Citations](#Citations)

# %% [markdown]
# # Purpose
# The purpose of this analysis package is to provide greater understanding of plant-pollinator networks and land management activities that improve pollinator habitat through Data-Visualization using Python Packages. The aim of the Pollinator Library is to support management and research of plant-pollinator systems by documenting, synthesizing, and disseminating information on flowers that are utilized by pollinators and other insects.

# %% [markdown]
# # Dependencies
#
# Several software packages are required to run this scientific code in a Jupyter notebook.
#
# ## Python and Anaconda installation <a class="anchor" id="Python-and-Anaconda-installation"></a>
#
# Instructions on installing the software environment is available at the(https://www.anaconda.com/download/). Conda is a powerful package manager and environment manager that you use with command line commands at the Anaconda Prompt for Windows, or in a Terminal window for macOS or Linux..
#
# ## A Python kernel for Jupyter notebooks <a class="anchor" id="A-Python-kernel-for-Jupyter-notebooks"></a>
#
#  This notebook uses [Python3 Kernel](https://ipython.readthedocs.io/en/latest/install/kernel_install.html).

# %% [markdown]
# ## Load the Python Packages <a class="anchor" id="Load-the-Python-Packages"></a>

# %%
import io, os, sys, types

# %%
import nbformat

from IPython import get_ipython
from IPython.core.interactiveshell import InteractiveShell
from collections import defaultdict,Counter, namedtuple
from operator import itemgetter, attrgetter
from urllib.request import Request, urlopen
from pandas.io.json import json_normalize
import json
import pandas as pd
import shlex
from IPython.display import display, Javascript, HTML
import folium
import plotly.plotly as py
import plotly.graph_objs as go
import itertools 
from itertools import groupby
import iplotter
from ipysankeywidget import SankeyWidget
import plotly
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='abhimike17', api_key='YtVTWLxeARvUWeNYurX7')

# %%
# # Import the REST API Web Service and filter the data
# api = Request('http://127.0.0.1:8000/pdatas/')
# Iapi = Request('http://127.0.0.1:8000/locations/')
# Papi = Request('http://127.0.0.1:8000/locationspsearch/')


# json_obj = urlopen(api)
# pdata = json.load(json_obj)

# Ijson_obj = urlopen(Iapi)
# locI = json.load(Ijson_obj)

# Pjson_obj = urlopen(Papi)
# locP = json.load(Pjson_obj)
with open('csvjson (5).json') as f:
    data = json.load(f)

# %%
y = filter(lambda x:x['insect'] == "Bombus rufocinctus", data)
x = list(y)
lat = Counter(k['latitude'] for k in x)
long = Counter(k['longitude'] for k in x)

# %%
latlist = []
longlist = []
count = []
for k in lat:
    if k not in latlist:
        latlist.append(k)
        
for k in long:
    if k not in longlist:
        longlist.append(k)

# %%
p = Counter(k['plant'] for k in x)
print(p)
# Out:
# Counter({'Pedicularis groenlandica': 161, 'Pedicularis attollens': 51, 'Pedicularis crenulata': 4, 'Amorpha canescens': 2, 'Dalea purpurea': 2, 'Asclepias syriaca': 1, 'Malus sylvestris': 1, 'Bromus inermis': 1, 'Lactuca tatarica': 1, 'Spiraea alba': 1, 'Symphoricarpos occidentalis': 1, 'Oligoneuron rigidum': 1})

# %%
i = []
for k in p:
    if k not in i:
        i.append(k)
        print(k)

print(i)
# Out:
# Asclepias syriaca
# Malus sylvestris
# Pedicularis crenulata
# Pedicularis attollens
# Pedicularis groenlandica
# Bromus inermis
# Amorpha canescens
# Lactuca tatarica
# Spiraea alba
# Dalea purpurea
# Symphoricarpos occidentalis
# Oligoneuron rigidum
# ['Asclepias syriaca', 'Malus sylvestris', 'Pedicularis crenulata', 'Pedicularis attollens', 'Pedicularis groenlandica', 'Bromus inermis', 'Amorpha canescens', 'Lactuca tatarica', 'Spiraea alba', 'Dalea purpurea', 'Symphoricarpos occidentalis', 'Oligoneuron rigidum']

# %%
df_counters = pd.DataFrame(
    {
     'latitude' : latlist,
     'longitude' : longlist,
        'plant': i
    })
df_counters.head()
# Out:
#    latitude  longitude                     plant
# 0  42.70929  -88.23171         Asclepias syriaca
# 1  42.67807  -88.27620          Malus sylvestris
# 2  39.37726 -105.80060     Pedicularis crenulata
# 3  37.88588 -119.25700     Pedicularis attollens
# 4  37.91500 -119.26200  Pedicularis groenlandica

# %%
locations = df_counters[['latitude','longitude']]
locationlist=locations.values.tolist()
len(locationlist)
print(locationlist)
newlist = []
for k in locationlist:
    j = [float(i) for i in k]
    if j not in newlist:
        newlist.append(j)
print(newlist[1])
# Out:
# [[42.70929, -88.23171], [42.67807, -88.2762], [39.37726, -105.8006], [37.88588, -119.257], [37.915, -119.262], [47.91342782, -99.03414694], [47.96734969, -98.99697661], [47.96427117, -99.00106265], [47.96492885, -98.99932748], [47.97031627, -98.99707456], [47.96478892, -98.99795614], [47.30184, -97.58368]]
# [42.67807, -88.2762]

# %%
import folium

# %%
map = folium.Map(location=[42.70929, -88.23171], zoom_start=5,     tiles='Stamen Terrain'
)
for point in range(0, len(locationlist)):
    folium.Marker(newlist[point], popup=df_counters['plant'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
yi = filter(lambda x:x['insect'] == "Apis mellifera", data)
xi = list(yi)
lo = []
for k in xi:
    lo.append(k['latitude'])
xi
# Out:
# [{'plkey': 1,
#   'pollinatorLibraryID': '01_1965WI_001',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2,
#   'pollinatorLibraryID': '01_1965WI_002',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 3,
#   'pollinatorLibraryID': '01_1965WI_003',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 4,
#   'pollinatorLibraryID': '01_1965WI_004',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 5,
#   'pollinatorLibraryID': '01_1965WI_005',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 6,
#   'pollinatorLibraryID': '01_1965WI_006',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 7,
#   'pollinatorLibraryID': '01_1965WI_007',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 8,
#   'pollinatorLibraryID': '01_1965WI_008',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 9,
#   'pollinatorLibraryID': '01_1965WI_009',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 10,
#   'pollinatorLibraryID': '01_1965WI_010',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 11,
#   'pollinatorLibraryID': '01_1965WI_011',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 12,
#   'pollinatorLibraryID': '01_1965WI_012',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620626,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 13,
#   'pollinatorLibraryID': '01_1965WI_013',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 14,
#   'pollinatorLibraryID': '01_1965WI_014',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 15,
#   'pollinatorLibraryID': '01_1965WI_015',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 16,
#   'pollinatorLibraryID': '01_1965WI_016',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 17,
#   'pollinatorLibraryID': '01_1965WI_017',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 18,
#   'pollinatorLibraryID': '01_1965WI_018',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 19,
#   'pollinatorLibraryID': '01_1965WI_019',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 20,
#   'pollinatorLibraryID': '01_1965WI_020',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 21,
#   'pollinatorLibraryID': '01_1965WI_021',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 22,
#   'pollinatorLibraryID': '01_1965WI_022',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 23,
#   'pollinatorLibraryID': '01_1965WI_023',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 24,
#   'pollinatorLibraryID': '01_1965WI_024',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620627,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 25,
#   'pollinatorLibraryID': '01_1965WI_025',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 26,
#   'pollinatorLibraryID': '01_1965WI_026',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 27,
#   'pollinatorLibraryID': '01_1965WI_027',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 28,
#   'pollinatorLibraryID': '01_1965WI_028',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 29,
#   'pollinatorLibraryID': '01_1965WI_029',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 30,
#   'pollinatorLibraryID': '01_1965WI_030',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 31,
#   'pollinatorLibraryID': '01_1965WI_031',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19620628,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
# ...
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2049,
#   'pollinatorLibraryID': '01_1965WI_759',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2050,
#   'pollinatorLibraryID': '01_1965WI_760',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2051,
#   'pollinatorLibraryID': '01_1965WI_761',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2052,
#   'pollinatorLibraryID': '01_1965WI_762',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2053,
#   'pollinatorLibraryID': '01_1965WI_763',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2054,
#   'pollinatorLibraryID': '01_1965WI_764',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2055,
#   'pollinatorLibraryID': '01_1965WI_765',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630704,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2065,
#   'pollinatorLibraryID': '01_1965WI_775',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630705,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2066,
#   'pollinatorLibraryID': '01_1965WI_776',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630705,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  {'plkey': 2067,
#   'pollinatorLibraryID': '01_1965WI_777',
#   'physicalLocationOfInsectSpecimen': 'Specimen not retained',
#   'determinedBy': 'Karl V. Krombien, Kenneth MacArthur, John T. Medler',
#   'insectOrder': 'Hymenoptera',
#   'insectFamily': 'Apidae',
#   'insectSubfamily': 'Apinae',
#   'insectTribe': 'Apini',
#   'insectGenus': 'Apis',
#   'insectSubgenus': 'Apis',
#   'insectSpecies': 'mellifera',
#   'insect': 'Apis mellifera',
#   'sex': 'Female',
#   'date': 19630705,
#   'time': 'N/A',
#   'timeZone': 'CST',
#   'collectedBy': 'Lazarus W. Macior',
#   'collectionMethod': 'Aerial Net',
#   'observedBehaviorOfInsectVisitor': 'N/A',
#   'plantOrder': 'Gentianales',
#   'plantFamily': 'Asclepiadaceae',
#   'plantGenus': 'Asclepias',
#   'plantSpecies': 'syriaca',
#   'plant': 'Asclepias syriaca',
#   'plantVariety': 'N/A',
#   'plantNativeStatus': 'Native',
#   'insectFieldID': 'N/A',
#   'landUse': 'Rangeland',
#   'siteDescription': 'Wet mesic prairie, moderately grazed',
#   'conservationPracticeNumber': 'N/A',
#   'siteName': 'N/A',
#   'state': 'Wisconsin',
#   'county': 'Racine',
#   'elevation': 241,
#   'longitude': -88.23171,
#   'latitude': 42.70929,
#   'averageWindSpeed': 'N/A',
#   'temperature': 'N/A',
#   'relativeHumidity': 'N/A',
#   'originResearchFacility': 'St. Francis College, Burlington, WI (closed in 1969)',
#   'contact': 'Dr. Steve Weeks',
#   'contactEmail': 'scweeks@uakron.edu',
#   'contactAddress': '200E Exc 160, University of Akron (Dept. of Biology), Akron, OH',
#   'contactPhoneNumber': '330-972-6954',
#   'comments': 'Collection Details: Time Range: 8:00-17:00'},
#  ...]

# %% [markdown]
# # Inputs
# The operational Pollinator Analysis Prototype retrieves data in real-time from the (https://www.npwrc.usgs.gov/pollinator/)'s REST API Web Processing Service.

# %%
# #Mention the Taxon for search and get the desired output
y = filter(lambda x:x['insecttaxon'] == "Apis mellifera", pdata)
x = list(y)
df = pd.DataFrame(x)
anp = df.groupby(['insectgenus','planttaxon']).size().reset_index(name = 'count')
anp.columns = ['source','target','value']
xbyz = anp.T.to_dict().values()

xcf = []

for k in xbyz:
    if k not in xcf:
        xcf.append(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-91d84b5aa142> in <module>()
#       1 # #Mention the Taxon for search and get the desired output
# ----> 2 y = filter(lambda x:x['insecttaxon'] == "Apis mellifera", pdata)
#       3 x = list(y)
#       4 df = pd.DataFrame(x)
#       5 anp = df.groupby(['insectgenus','planttaxon']).size().reset_index(name = 'count')
#
# NameError: name 'pdata' is not defined

# %%
links = xcf

# %%
w = SankeyWidget(links=links, margins=dict(top=0, bottom=0, left=100, right=200))

# %%
w

# %%
# Get the latitude and longitude position of the taxon 

lat = Counter(k['latitude'] for k in xi)
long = Counter(k['longitude'] for k in xi)

latlist = []
longlist = []
count = []

for k in xi:
#     if k not in latlist:
        latlist.append(k['latitude'])

for k in xi:
#     if k not in longlist:
        longlist.append(k['longitude'])
# Get the interation list of Taxon depending on the search
p = Counter(k['planttaxon'] for k in xi)

# list of Plants
i = []
for k in xi:
        i.append(k['planttaxon'])

# %% [markdown]
# # Outputs

# %% [markdown]
# ## Tabular Data <a class="anchor" id="Tabular-Data"></a>

# %%
#Data of Location and taxon interaction
df_counters = pd.DataFrame(
    {
     'latitude' : latlist,
     'longitude' : longlist,
        'planttaxon': i
    })

# %% [markdown]
# ## Map
# Produce a Leaflet Map of all modeled location results for Pollinator interactions.

# %%
locations = df_counters[['latitude','longitude']]
locationlist=locations.values.tolist()
len(locationlist)
newlist = []
for k in locationlist:
    j = [float(i) for i in k]
    newlist.append(j)
# len(locationlist)

# %%
# produce a Leaflet map with all Taxon locations
map = folium.Map(location=[39.048603, -94.116578], zoom_start=4, tiles='Stamen Terrain'
)
for point in range(0, len(locationlist)):
    folium.Marker(newlist[point], popup=df_counters['planttaxon'][point]).add_to(map)
map

# %% [markdown]
# ## Bar Chart <a class="anchor" id="Bar-Chart"></a>
# Produce bar chart of the modeled results.

# %%
# Interaction of each plant
count = []
for k in xi:
    count.append(k['count'])

    j = []
for k in xi:
    j.append(k['planttaxon'])
    
data = [go.Bar(
            x=count,
            y=j,
            orientation = 'h'
)]


layout = go.Layout(
    autosize=True,
    width=800,
    height=800,
    yaxis=go.layout.YAxis(
        title='',
      
        tickmode='array',
        automargin=True,
        titlefont=dict(size=10),
    ),
  
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='automargin')
# py.iplot(data, filename='horizontal-bar')

# %%
def landuse(name):
#     name = "USFWS National Wildlife Refuge"
    zy = filter(lambda x:x['landuse'] == name, xi)
    zyp = list(zy)
    
    pl = []
    for k in zyp:
            pl.append(k['planttaxon'])

    jl = []
    for k in zyp:
        jl.append(k['count'])
        
   
    return pl, jl
mn, nm = landuse("USFWS National Wildlife Refuge")
man, nam = landuse("USDA Conservation Reserve Program")
abc, bac = landuse("Rangeland")

# %%
trace1 = go.Bar(
    y=man,
    x=nam,
    name='USDA Conservation Reserve Program',
    orientation = 'h',
    marker = dict(
        color = 'rgba(128, 0, 0, 0.60)',
        line = dict(
            color = 'rgba(128, 0, 0, 0.60)',
            width = 3)
    )
)
trace2 = go.Bar(
    y=mn,
    x=nm,
    name='USFWS National Wildlife Refuge',
    orientation = 'h',
    marker = dict(
        color = 'rgba(58, 71, 80, 0.6)',
        line = dict(
            color = 'rgba(58, 71, 80, 1.0)',
            width = 3)
    )
)
trace3 = go.Bar(
    y=abc,
    x=bac,
    name='Rangeland',
    orientation = 'h',
    marker = dict(
        color = 'rgba(0, 0, 128, 0.6)',
        line = dict(
            color = 'rgba(0, 0, 128, 1.0)',
            width = 3)
    )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='stack',
    yaxis=go.layout.YAxis(
        title='',
      
        tickmode='array',
        automargin=True,
        titlefont=dict(size=20),
    ),
    
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar')

# %% [markdown]
# # Code
# Code is available at the

# %% [markdown]
# # Provenance

# %% [markdown]
# # Citations
# R Code for Otto, CRV, RB Bryant, NH Euliss Jr., S O'Dell, R Bush, and MD Smart. (2017). Using Publicly Available Data to Quantify Plant-Pollinator Interactions and Evaluate Conservation Seeding Mixes in the Northern Great Plains ###Analysis of data from Pollinator Library
#
# R Code prepared by Clint Otto, US Geological Survey, Northern Prairie Wildlife Research Center
#
# Analysis started on 06.20.2016
#
# Code altered to provide Dan Wieferich with an example of how to take data from the Library,
# and provide users with graphs and descriptive data. 02.02.2018
